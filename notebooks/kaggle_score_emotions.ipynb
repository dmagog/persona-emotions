# %% [markdown]
# # Score emotion responses with the classifier encoder
#
# Runs `emotion.score_csv` on the generated Qwen2.5-3B responses, encoding each
# answer with a GoEmotions classifier aggregated to the 7 ISEAR emotions, and
# reports per-emotion `shift` (pos vs neg mean) and `auc` (separability of
# positive vs neutral responses).
#
# Run this on Kaggle (or Colab): the local macOS torch build crashes on inference.

# %%
# !git clone --branch emotion-encoder --depth 1 https://github.com/dmagog/persona-emotions.git
# %cd persona-emotions

# %%
# !pip install -q -U transformers

# %%
# Full run across all 7 ISEAR emotions. Drop --limit for the complete dataset;
# add e.g. --limit 50 for a quick check. Writes a results CSV (fetched as kernel output).
# !python -m emotion.score_csv --data-dir eval_emotion/Qwen2.5-3B-Instruct --emotion all --out results/encoder_scoring_qwen2.5-3b.csv
